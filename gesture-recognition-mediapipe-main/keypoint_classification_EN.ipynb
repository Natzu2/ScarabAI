# %%
import csv
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42

# %% [markdown]
# # Specify each path

# %%
#dataset = 'model/keypoint.csv'
model_save_path = 'model/keypoint_classifier/keypoint_classifier.hdf5'
tflite_save_path = 'model/keypoint_classifier/keypoint_classifier.tflite'

# %% [markdown]
# # Set number of classes

# %%
NUM_CLASSES = 4

# %% [markdown]
# # Dataset reading

# %%
import os
contenido_izq = os.listdir('data/Luis Mano Derecha/')
contenido_der = os.listdir('data/Luis Mano Izquierda/')
#print("data izq", contenido_izq)
#print("data der", contenido_der)

X0_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[0], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[0], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))) ))
print(contenido_der[0],len(X0_dataset))

X1_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[1], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[1], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))) ))
print(contenido_der[1],len(X1_dataset))
X2_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[2], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[2], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))) ))
print(contenido_der[2],len(X2_dataset))
X3_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[3], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[3], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))) ))
print(contenido_der[3],len(X3_dataset))
X4_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[4], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[4], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))) ))
print(contenido_der[4],len(X4_dataset))
X5_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[5], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[5], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))) ))
print(contenido_der[5],len(X5_dataset))
X6_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[6], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[6], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))) ))
print(contenido_der[6],len(X6_dataset))
X7_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[7], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[7], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))) ))
print(contenido_der[7],len(X7_dataset))
X8_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[8], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[8], delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1))) ))
print(contenido_der[8],len(X8_dataset))
# Out:
# gesto 0.csv 1000
# gesto 1.csv 1000
# gesto 2.csv 1000
# gesto 3.csv 1000
# gesto 4.csv 1000
# gesto 5.csv 1000
# gesto 6.csv 1000
# gesto 7.csv 1000
# gesto 8.csv 1000

# %%
y0_dataset = np.loadtxt('data/Luis Mano Derecha/'+contenido_der[0], delimiter=',', dtype='int32', usecols=(0))

Y0_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[0], delimiter=',', dtype='int32', usecols=(0)), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[0], delimiter=',', dtype='int32', usecols=(0)) ))
print(len(Y0_dataset), "0")

Y1_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[1], delimiter=',', dtype='int32', usecols=(0)), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[1], delimiter=',', dtype='int32', usecols=(0)) ))
print(len(Y1_dataset), "1")

Y2_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[2], delimiter=',', dtype='int32', usecols=(0)), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[2], delimiter=',', dtype='int32', usecols=(0)) ))
print(len(Y2_dataset), "2")

Y3_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[3], delimiter=',', dtype='int32', usecols=(0)), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[3], delimiter=',', dtype='int32', usecols=(0)) ))
print(len(Y3_dataset), "3")

Y4_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[4], delimiter=',', dtype='int32', usecols=(0)), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[4], delimiter=',', dtype='int32', usecols=(0)) ))
print(len(Y4_dataset), "4")

Y5_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[5], delimiter=',', dtype='int32', usecols=(0)), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[5], delimiter=',', dtype='int32', usecols=(0)) ))
print(len(Y5_dataset), "5")

Y6_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[6], delimiter=',', dtype='int32', usecols=(0)), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[6], delimiter=',', dtype='int32', usecols=(0)) ))
print(len(Y6_dataset), "6")

Y7_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[7], delimiter=',', dtype='int32', usecols=(0)), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[7], delimiter=',', dtype='int32', usecols=(0)) ))
print(len(Y7_dataset), "7")

Y8_dataset = np.concatenate((np.loadtxt('data/Luis Mano Derecha/'+contenido_der[8], delimiter=',', dtype='int32', usecols=(0)), 
np.loadtxt('data/Luis Mano Izquierda/'+contenido_izq[8], delimiter=',', dtype='int32', usecols=(0)) ))
print(len(Y8_dataset), "8")
# Out:
# 1000 0
# 1000 1
# 1000 2
# 1000 3
# 1000 4
# 1000 5
# 1000 6
# 1000 7
# 1000 8

# %%
X0_train, X0_test, Y0_train, Y0_test = train_test_split(X0_dataset, Y0_dataset, train_size=0.75, random_state=RANDOM_SEED)
X1_train, X1_test, Y1_train, Y1_test = train_test_split(X1_dataset, Y1_dataset, train_size=0.75, random_state=RANDOM_SEED)
X2_train, X2_test, Y2_train, Y2_test = train_test_split(X2_dataset, Y2_dataset, train_size=0.75, random_state=RANDOM_SEED)
X3_train, X3_test, Y3_train, Y3_test = train_test_split(X3_dataset, Y3_dataset, train_size=0.75, random_state=RANDOM_SEED)
X4_train, X4_test, Y4_train, Y4_test = train_test_split(X4_dataset, Y4_dataset, train_size=0.75, random_state=RANDOM_SEED)
X5_train, X5_test, Y5_train, Y5_test = train_test_split(X5_dataset, Y5_dataset, train_size=0.75, random_state=RANDOM_SEED)
X6_train, X6_test, Y6_train, Y6_test = train_test_split(X6_dataset, Y6_dataset, train_size=0.75, random_state=RANDOM_SEED)
X7_train, X7_test, Y7_train, Y7_test = train_test_split(X7_dataset, Y7_dataset, train_size=0.75, random_state=RANDOM_SEED)

X8_train, X8_test, Y8_train, Y8_test = train_test_split(X8_dataset, Y8_dataset, train_size=0.75, random_state=RANDOM_SEED)
print(len(X0_train), len(Y0_train), "0")
print(len(X1_train), len(Y1_train), "1")
print(len(X2_train), len(Y2_train), "2")
print(len(X3_train), len(Y3_train), "3")
print(len(X4_train), len(Y4_train), "4")
print(len(X5_train), len(Y5_train), "5")
print(len(X6_train), len(Y6_train), "6")
print(len(X7_train), len(Y7_train), "7")
print(len(X8_train), len(Y8_train), "8")

X_train = np.concatenate((X0_train,X1_train,X2_train,X3_train,X4_train,X5_train,X6_train,X7_train,X8_train))
X_test = np.concatenate((X0_test,X1_test,X2_test,X3_test,X4_test,X5_test,X6_test,X7_test,X8_test))

Y_train = np.concatenate((Y0_train,Y1_train,Y2_train,Y3_train,Y4_train,Y5_train,Y6_train,Y7_train,Y8_train))
Y_test = np.concatenate((Y0_test,Y1_test,Y2_test,Y3_test,Y4_test,Y5_test,Y6_test,Y7_test,Y8_test))

print(len(X_train), "X_train")
print(len(X_test), "X_test")
print(len(Y_train), "Y_train")
print(len(Y_test), "Y_test")
# Out:
# 750 750 0
# 750 750 1
# 750 750 2
# 750 750 3
# 750 750 4
# 750 750 5
# 750 750 6
# 750 750 7
# 750 750 8
# 6750 X_train
# 2250 X_test
# 6750 Y_train
# 2250 Y_test

# %%
load_model = tf.keras.models.load_model("./model/keypoint_classifier/keypoint_classifier.hdf5")
load_model.summary()# Model compilation
load_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
val_loss, val_acc = load_model.evaluate(X_test, Y_test, batch_size=128)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 20)                860
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 9)                 99
#
# ...
# Total params: 1,169
# Trainable params: 1,169
# Non-trainable params: 0
# _________________________________________________________________
# 18/18 [==============================] - 0s 824us/step - loss: 0.0101 - accuracy: 0.9978

# %% [markdown]
# # Model building

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((21 * 2, )),
    tf.keras.layers.Dense(20, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(9, activation='softmax')
])

# %%
model.summary()  # tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 20)                860
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 9)                 99
#
# ...
# Total params: 1,169
# Trainable params: 1,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model checkpoint callback
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
# Callback for early stopping
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)

# %%
# Model compilation
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # Model training

# %%
model.fit(
    X_train,
    Y_train,
    epochs=1000,
    batch_size=128,
    validation_data=(X_test, Y_test),
    callbacks=[cp_callback, es_callback]
)
# Out:
# Epoch 1/1000
#  1/53 [..............................] - ETA: 20s - loss: 2.3231 - accuracy: 0.0625
# Epoch 1: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 53/53 [==============================] - 1s 3ms/step - loss: 2.1114 - accuracy: 0.1444 - val_loss: 1.9735 - val_accuracy: 0.1591
# Epoch 2/1000
#  1/53 [..............................] - ETA: 0s - loss: 1.9814 - accuracy: 0.1406
# Epoch 2: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 53/53 [==============================] - 0s 2ms/step - loss: 1.8390 - accuracy: 0.2840 - val_loss: 1.6784 - val_accuracy: 0.4098
# Epoch 3/1000
#  1/53 [..............................] - ETA: 0s - loss: 1.6874 - accuracy: 0.4219
# Epoch 3: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 53/53 [==============================] - 0s 2ms/step - loss: 1.5064 - accuracy: 0.5393 - val_loss: 1.3177 - val_accuracy: 0.6569
# Epoch 4/1000
# ...

# %%
# Model evaluation
val_loss, val_acc = model.evaluate(X_test, Y_test, batch_size=128)
# Out:
# 18/18 [==============================] - 0s 647us/step - loss: 0.0101 - accuracy: 0.9978

# %%
# Loading the saved model
model = tf.keras.models.load_model(model_save_path)

# %%
# Inference test
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))
# Out:
# 1/1 [==============================] - 0s 62ms/step
# [9.9991345e-01 2.3894567e-12 2.9300125e-13 4.1432767e-08 1.6591747e-11
#  1.3256794e-10 3.0006710e-08 3.4177158e-06 8.3025552e-05]
# 0

# %% [markdown]
# # Confusion matrix

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()
    
    if report:
        print('Classification Report')
        print(classification_report(Y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(Y_test, y_pred)
# Out:
# 71/71 [==============================] - 0s 534us/step
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       250
#            1       1.00      1.00      1.00       250
#            2       1.00      1.00      1.00       250
#            3       1.00      1.00      1.00       250
#            4       1.00      1.00      1.00       250
#            5       1.00      1.00      1.00       250
#            6       1.00      1.00      1.00       250
#            7       1.00      1.00      1.00       250
#            8       1.00      0.99      0.99       250
#
#     accuracy                           1.00      2250
#    macro avg       1.00      1.00      1.00      2250
# weighted avg       1.00      1.00      1.00      2250

# %% [markdown]
# # Convert to model for Tensorflow-Lite

# %%
# Save as a model dedicated to inference
model.save(model_save_path, include_optimizer=False)

# %%
# Transform model (quantization)

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quantized_model = converter.convert()

open(tflite_save_path, 'wb').write(tflite_quantized_model)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\spoon\AppData\Local\Temp\tmpi2dayekj\assets
# INFO:tensorflow:Assets written to: C:\Users\spoon\AppData\Local\Temp\tmpi2dayekj\assets
# 6776

# %% [markdown]
# # Inference test

# %%
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()

# %%
# Get I / O tensor
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
interpreter.set_tensor(input_details[0]['index'], np.array([X_test[0]]))

# %%
# %%time
# Inference implementation
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]['index'])
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
print(np.squeeze(tflite_results))
print(np.argmax(np.squeeze(tflite_results)))
# Out:
# [9.9991345e-01 2.3894749e-12 2.9300352e-13 4.1432923e-08 1.6591810e-11
#  1.3256919e-10 3.0006824e-08 3.4177287e-06 8.3025960e-05]
# 0
